# %%
#Data analysis and manipulation tool
import pandas as pd
#Wide variety of mathematical operations on arrays
import numpy as np
#Tool for plotting
import matplotlib.pyplot as plt
#Google Drive
from google.colab import drive

# %%
#Mount Google Drive to Google Colab
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
#Verify mount is correct
# !ls -l gdrive/MyDrive/Colab\ Notebooks/UPS-WIL-1/csv
# Out:
# total 183
# -rw------- 1 root root  56319 Mar 16 08:35 vg_vr_vb_vi_wil_1.txt
# -rw------- 1 root root 130486 Mar 22 16:54 vg_vr_vb_vi_wil_2.txt

# %%
#The "read_csv" method allows us to read a CSV
data_mult = pd.read_csv("gdrive/MyDrive/Colab Notebooks/UPS-WIL-1/csv/vg_vr_vb_vi_wil_2.txt", header = None)
#Cov = pd.read_csv("path/to/file.txt", sep='\t', header=None)
data_mult.columns = ["ID", "Voltaje Red Eléctrica", "Voltaje Relay Inversor", "Voltaje Batería", "Voltaje Encender Inversor", "ClientIP", "SensorID", "DateTime"]

# %%
#Show information about dataset
data_mult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2009 entries, 0 to 2008
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         2009 non-null   int64
#  1   Voltaje Red Eléctrica      2009 non-null   float64
#  2   Voltaje Relay Inversor     2009 non-null   float64
#  3   Voltaje Batería            2009 non-null   float64
#  4   Voltaje Encender Inversor  2009 non-null   float64
#  5   ClientIP                   2009 non-null   object
#  6   SensorID                   2009 non-null   object
#  7   DateTime                   2009 non-null   object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 125.7+ KB

# %%
#Show first rows of dataset
data_mult.head()
# Out:
#     ID  Voltaje Red Eléctrica  Voltaje Relay Inversor  Voltaje Batería  \
# 0  901                   6.23                    0.74            11.91
# 1  902                   6.37                    0.82            12.05
# 2  903                   6.31                    0.78            12.17
# 3  904                   6.29                    0.74            12.15
# 4  905                   6.31                    0.70            12.19
#
#    Voltaje Encender Inversor     ClientIP SensorID             DateTime
# 0                       6.31  179.6.8.219   WIL-01  2026-03-22 00:37:28
# 1                       6.43  179.6.8.219   WIL-01  2026-03-22 00:37:29
# 2                       6.45  179.6.8.219   WIL-01  2026-03-22 00:37:31
# 3                       6.41  179.6.8.219   WIL-01  2026-03-22 00:37:32
# 4                       6.43  179.6.8.219   WIL-01  2026-03-22 00:37:33

# %%
#Show statistics of dataset
data_mult.describe()
# Out:
#                 ID  Voltaje Red Eléctrica  Voltaje Relay Inversor  \
# count  2009.000000            2009.000000             2009.000000
# mean   1905.000000               1.371613                4.315575
# std     580.092665               1.859380                1.339170
# min     901.000000               0.590000                0.430000
# 25%    1403.000000               0.660000                4.800000
# 50%    1905.000000               0.680000                4.800000
# 75%    2407.000000               0.680000                4.840000
# max    2909.000000               6.540000                5.020000
#
#        Voltaje Batería  Voltaje Encender Inversor
# count      2009.000000                2009.000000
# mean         11.700786                   6.295655
# std           0.329259                   0.070950
# min          11.270000                   6.090000
# 25%          11.500000                   6.250000
# 50%          11.600000                   6.270000
# ...

# %%
#Show last rows of dataset
data_mult.tail()
# Out:
#         ID  Voltaje Red Eléctrica  Voltaje Relay Inversor  Voltaje Batería  \
# 2004  2905                   6.31                    0.64            12.60
# 2005  2906                   6.35                    0.74            12.56
# 2006  2907                   0.72                    4.84            12.44
# 2007  2908                   0.70                    4.82            12.30
# 2008  2909                   0.70                    4.80            12.23
#
#       Voltaje Encender Inversor     ClientIP SensorID             DateTime
# 2004                       6.37  179.6.8.219   WIL-01  2026-03-22 01:21:57
# 2005                       6.43  179.6.8.219   WIL-01  2026-03-22 01:21:59
# 2006                       6.37  179.6.8.219   WIL-01  2026-03-22 01:22:00
# 2007                       6.35  179.6.8.219   WIL-01  2026-03-22 01:22:01
# 2008                       6.37  179.6.8.219   WIL-01  2026-03-22 01:22:03

# %%
#Show sample of rows
data_mult.sample(5)
# Out:
#         ID  Voltaje Red Eléctrica  Voltaje Relay Inversor  Voltaje Batería  \
# 1270  2171                   0.68                    4.84            11.56
# 946   1847                   0.68                    4.86            11.64
# 1676  2577                   0.66                    4.84            11.50
# 2006  2907                   0.72                    4.84            12.44
# 1342  2243                   0.68                    4.79            11.52
#
#       Voltaje Encender Inversor     ClientIP SensorID             DateTime
# 1270                       6.27  179.6.8.219   WIL-01  2026-03-22 01:05:40
# 946                        6.27  179.6.8.219   WIL-01  2026-03-22 00:58:28
# 1676                       6.23  179.6.8.219   WIL-01  2026-03-22 01:14:41
# 2006                       6.37  179.6.8.219   WIL-01  2026-03-22 01:22:00
# 1342                       6.29  179.6.8.219   WIL-01  2026-03-22 01:07:16

# %%
#Percentage of unique rows (records)
data_mult.nunique() / len(data_mult)
# Out:
# ID                           1.000000
# Voltaje Red Eléctrica        0.012444
# Voltaje Relay Inversor       0.016924
# Voltaje Batería              0.035839
# Voltaje Encender Inversor    0.012444
# ClientIP                     0.000498
# SensorID                     0.000498
# DateTime                     1.000000
# dtype: float64

# %%
#Percentage of empty rows (records) ...
data_mult.isna().sum() / len(data_mult)
# Out:
# ID                           0.0
# Voltaje Red Eléctrica        0.0
# Voltaje Relay Inversor       0.0
# Voltaje Batería              0.0
# Voltaje Encender Inversor    0.0
# ClientIP                     0.0
# SensorID                     0.0
# DateTime                     0.0
# dtype: float64

# %%
#Data types
data_mult.dtypes
# Out:
# ID                             int64
# Voltaje Red Eléctrica        float64
# Voltaje Relay Inversor       float64
# Voltaje Batería              float64
# Voltaje Encender Inversor    float64
# ClientIP                      object
# SensorID                      object
# DateTime                      object
# dtype: object

# %%
#Show highest values of Output Temperature
data_mult_2 = data_mult.loc[(data_mult['DateTime'] > '2026-03-22 00:00:00') & (data_mult['DateTime'] < '2026-03-23 00:00:00')]

# %%
data_mult_2
# Out:
#         ID  Voltaje Red Eléctrica  Voltaje Relay Inversor  Voltaje Batería  \
# 0      901                   6.23                    0.74            11.91
# 1      902                   6.37                    0.82            12.05
# 2      903                   6.31                    0.78            12.17
# 3      904                   6.29                    0.74            12.15
# 4      905                   6.31                    0.70            12.19
# ...    ...                    ...                     ...              ...
# 2004  2905                   6.31                    0.64            12.60
# 2005  2906                   6.35                    0.74            12.56
# 2006  2907                   0.72                    4.84            12.44
# 2007  2908                   0.70                    4.82            12.30
# 2008  2909                   0.70                    4.80            12.23
#
# ...

# %%
#Data statistics
data_mult_2.describe()
# Out:
#                 ID  Voltaje Red Eléctrica  Voltaje Relay Inversor  \
# count  2009.000000            2009.000000             2009.000000
# mean   1905.000000               1.371613                4.315575
# std     580.092665               1.859380                1.339170
# min     901.000000               0.590000                0.430000
# 25%    1403.000000               0.660000                4.800000
# 50%    1905.000000               0.680000                4.800000
# 75%    2407.000000               0.680000                4.840000
# max    2909.000000               6.540000                5.020000
#
#        Voltaje Batería  Voltaje Encender Inversor
# count      2009.000000                2009.000000
# mean         11.700786                   6.295655
# std           0.329259                   0.070950
# min          11.270000                   6.090000
# 25%          11.500000                   6.250000
# 50%          11.600000                   6.270000
# ...

# %%
#Create a matrix to represent the x-axis of a graph
#x1 = np.arange(0, len(y), 1)
x2 = np.arange(0, len(data_mult_2["ID"]), 1)
x2
# Out:
# array([   0,    1,    2, ..., 2006, 2007, 2008])

# %%
#Select Electrical Grid Voltage variable
y2_vg = data_mult_2[["Voltaje Red Eléctrica"]]
print(y2_vg)
# Out:
#       Voltaje Red Eléctrica
# 0                      6.23
# 1                      6.37
# 2                      6.31
# 3                      6.29
# 4                      6.31
# ...                     ...
# 2004                   6.31
# 2005                   6.35
# 2006                   0.72
# 2007                   0.70
# 2008                   0.70
#
# [2009 rows x 1 columns]

# %%
#Electrical Grid Voltage vs Time
plt.figure(figsize=(24,10))
plt.title("Electrical Grid Voltage vs Time", fontsize = 16)
plt.scatter(x2, y2_vg, s=5, color="red", label="Electrical Grid Voltage")
plt.plot(x2, y2_vg, lw=0.8, color="blue", label="Electrical Grid Voltage")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('Electrical Grid Voltage', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
#Select Inverter Relay Voltage variable
y2_vr = data_mult_2[["Voltaje Relay Inversor"]]
print(y2_vr)
# Out:
#       Voltaje Relay Inversor
# 0                       0.74
# 1                       0.82
# 2                       0.78
# 3                       0.74
# 4                       0.70
# ...                      ...
# 2004                    0.64
# 2005                    0.74
# 2006                    4.84
# 2007                    4.82
# 2008                    4.80
#
# [2009 rows x 1 columns]

# %%
#Inverter Relay Voltage vs Time
plt.figure(figsize=(24,10))
plt.title("Inverter Relay Voltage vs Time", fontsize = 16)
plt.scatter(x2, y2_vr, s=5, color="red", label="Inverter Relay Voltage")
plt.plot(x2, y2_vr, lw=0.8, color="blue", label="Inverter Relay Voltage")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('Inverter Relay Voltage', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
#Select Battery Voltage variable
y2_vb = data_mult_2[["Voltaje Batería"]]
print(y2_vb)
# Out:
#       Voltaje Batería
# 0               11.91
# 1               12.05
# 2               12.17
# 3               12.15
# 4               12.19
# ...               ...
# 2004            12.60
# 2005            12.56
# 2006            12.44
# 2007            12.30
# 2008            12.23
#
# [2009 rows x 1 columns]

# %%
#Battery Voltage vs Time
plt.figure(figsize=(24,10))
plt.title("Battery Voltage vs Time", fontsize = 16)
plt.scatter(x2, y2_vb, s=5, color="red", label="Battery Voltage")
plt.plot(x2, y2_vb, lw=0.8, color="blue", label="Battery Voltage")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('Battery Voltage', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
#Select Voltage to Power On Inverter variable
y2_vi = data_mult_2[["Voltaje Encender Inversor"]]
print(y2_vi)
# Out:
#       Voltaje Encender Inversor
# 0                          6.31
# 1                          6.43
# 2                          6.45
# 3                          6.41
# 4                          6.43
# ...                         ...
# 2004                       6.37
# 2005                       6.43
# 2006                       6.37
# 2007                       6.35
# 2008                       6.37
#
# [2009 rows x 1 columns]

# %%
#Voltage Power On Inverter vs Time
plt.figure(figsize=(24,10))
plt.title("Voltage Power On Inverter vs Time", fontsize = 16)
plt.scatter(x2, y2_vi, s=5, color="red", label="Voltage Power On Inverter")
plt.plot(x2, y2_vi, lw=0.8, color="blue", label="Voltage Power On Inverter")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('Voltage Power On Inverter', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
# create figure
fig = plt.figure(figsize=(20, 10))
plt.title("Electrical Grid - Inverter Relay - Battery - Power On Inverter (Voltages) vs Time", fontsize = 16)

# setting values to rows and column variables
rows = 4
columns = 1

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)

#Showing image
#Electrical Grid Voltage vs Time
plt.scatter(x2, y2_vg, s=5, color="red", label="Electrical Grid Voltage")
plt.plot(x2, y2_vg, lw=0.8, color="blue", label="Electrical Grid Voltage")
#plt.xticks(fontsize = 16)
#plt.yticks(fontsize = 16)
#plt.xlabel('Tiempo', fontsize = 16)
plt.ylabel('Electrical Grid Voltage')
#plt.ylabel('Voltaje Panel', fontsize = 16)
#plt.legend(fontsize = 16)
plt.grid()
#plt.imshow(Image1)
#plt.axis('off')
#plt.title("First")

# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)

#Showing image
#Inverter Relay Voltage vs Time
plt.scatter(x2, y2_vr, s=5, color="red", label="Inverter Relay Voltage")
plt.plot(x2, y2_vr, lw=0.8, color="blue", label="Inverter Relay Voltage")
#plt.xticks(fontsize = 16)
#plt.yticks(fontsize = 16)
#plt.xlabel('Tiempo', fontsize = 16)
#plt.ylabel('Voltaje Batería', fontsize = 16)
plt.ylabel('Inverter Relay Voltage')
#plt.legend(fontsize = 16)
plt.grid()

#plt.imshow(Image2)
#plt.axis('off')
#plt.title("Second")

# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 3)

#Showing image
#Battery Voltage vs Time
plt.scatter(x2, y2_vb, s=5, color="red", label="Battery Voltage")
plt.plot(x2, y2_vb, lw=0.8, color="blue", label="Battery Voltage")
#plt.xticks(fontsize = 16)
#plt.yticks(fontsize = 16)
#plt.xlabel('Tiempo', fontsize = 16)
#plt.ylabel('Voltaje Batería', fontsize = 16)
plt.ylabel('Battery Voltage')
#plt.legend(fontsize = 16)
plt.grid()

#plt.imshow(Image2)
#plt.axis('off')
#plt.title("Second")

# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 4)

#Showing image
#Voltage to Power On Inverter vs Time
plt.scatter(x2, y2_vi, s=5, color="red", label="Voltage Power On Inverter")
plt.plot(x2, y2_vi, lw=0.8, color="blue", label="Voltage Power On Inverter")
#plt.xticks(fontsize = 16)
#plt.yticks(fontsize = 16)
#plt.xlabel('Tiempo', fontsize = 16)
#plt.ylabel('Voltaje Batería', fontsize = 16)
plt.ylabel('Voltage Power On Inverter')
#plt.legend(fontsize = 16)
plt.grid()

#plt.imshow(Image2)
#plt.axis('off')
#plt.title("Second")

# showing image
#plt.imshow(Image4)
#plt.axis('off')
#plt.title("Fourth")
#plt.grid()
plt.show()

# %%
#Temp In - Temp Out vs Time
plt.figure(figsize=(24,10))
plt.title("Electrical Grid - Inverter Relay - Battery - Power On Inverter (Voltages) vs Time", fontsize = 16)
#plt.scatter(x1, y1, s=5, color="red", label="Temp In")
plt.plot(x2, y2_vg, lw=1.8, color="green", label="Electrical GRid Voltage")
plt.plot(x2, y2_vr, lw=1.8, color="red", label="Inverter Relay Voltage")
plt.plot(x2, y2_vb, lw=1.8, color="blue", label="Battery Voltage")
plt.plot(x2, y2_vi, lw=1.8, color="orange", label="Voltage Power On Inverter")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('Electrical Grid - Inverter Relay - Battery - Power On Inverter (Voltages)', fontsize = 16)
plt.legend(fontsize = 16)
plt.grid()
plt.show()

# %%
#Overlapping variables
plt.figure(figsize=(24,10))
plt.title("Electrical grid state (D5) - Output switching (D6) - Battery voltage (Vb) - Signal to power on the inverter (D7) (Voltages) vs Time", fontsize = 16)
#plt.scatter(x1, y1, s=5, color="red", label="Temp In")
plt.plot(x2, y2_vg, lw=1.8, color="green", label="Electrical grid state (D5)")
plt.plot(x2, y2_vr, lw=1.8, color="red", label="Output switching (D6)")
plt.plot(x2, y2_vb, lw=1.8, color="blue", label="Battery voltage (Vb)")
plt.plot(x2, y2_vi, lw=1.8, color="orange", label="Signal to power on the inverter (D7)")
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('Time', fontsize = 16)
plt.ylabel('(D5) - (D6) - (Vb) - (D7)', fontsize = 16)
plt.legend(fontsize = 16, bbox_to_anchor=(1, 0.8))
plt.grid()
plt.show()
